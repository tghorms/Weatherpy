# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
api_key = "39042e07c1158e77a43c5d806d2b6125"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %%
#creating url 
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={api_key}&units={units}&q="

# %%
#creating lists to store extracted values per city
city_name = []
country = []
date = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []

#setting the counter values
record = 0
set_starter = 1

print("Beginning Data Retrieval")

print("--------------------------------")

#creating loop to extract values per city and add them to the lists above
for city in cities:
   
    try:
        response = requests.get(f"{query_url}{city}").json()
        #city_name.append(response["name"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        
        #creating a if statment to cycle through counter and reset counter to make set contain 50 cities
        if record > 49:
            record = 1
            set_starter += 1
            city_name.append(response["name"])
        else:
            record += 1
            city_name.append(response["name"])
            
        print(f"Processing Record {record} of Set {set_starter} | {city_record}")
        
        #using time.sleep to create time delay
        time.sleep(1.02)
              
    except :
              print("City not found. Skipping...")
              
    continue

print("-------------------------------")
print("Data Retrieval Complete")
print("-------------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of Set 1 | Port-Gentil
# City not found. Skipping...
# Processing Record 2 of Set 1 | Mataura
# City not found. Skipping...
# Processing Record 3 of Set 1 | Ushuaia
# Processing Record 4 of Set 1 | Sobolevo
# Processing Record 5 of Set 1 | Vaini
# City not found. Skipping...
# Processing Record 6 of Set 1 | Albany
# Processing Record 7 of Set 1 | Salalah
# Processing Record 8 of Set 1 | Bredasdorp
# Processing Record 9 of Set 1 | Beruwala
# Processing Record 10 of Set 1 | Kapaa
# Processing Record 11 of Set 1 | Islamkot
# Processing Record 12 of Set 1 | Sulangan
# Processing Record 13 of Set 1 | Tasiilaq
# City not found. Skipping...
# Processing Record 14 of Set 1 | Gagino
# City not found. Skipping...
# Processing Record 15 of Set 1 | Tucurui
# Processing Record 16 of Set 1 | Busselton
# Processing Record 17 of Set 1 | Merauke
# Processing Record 18 of Set 1 | Cape Town
# Processing Record 19 of Set 1 | Ostrovnoy
# City not found. Skipping...
# Processing Record 20 of Set 1 | Mackenzie
# City not found. Skipping...
# Processing Record 21 of Set 1 | Bilibino
# Processing Record 22 of Set 1 | Ilulissat
# Processing Record 23 of Set 1 | Saint-Philippe
# Processing Record 24 of Set 1 | Leshukonskoye
# Processing Record 25 of Set 1 | Tuatapere
# Processing Record 26 of Set 1 | Elizabeth City
# Processing Record 27 of Set 1 | Vila Franca do Campo
# Processing Record 28 of Set 1 | East London
# Processing Record 29 of Set 1 | Salamiyah
# Processing Record 30 of Set 1 | Orlik
# Processing Record 31 of Set 1 | Derzhavinsk
# Processing Record 32 of Set 1 | Ketchikan
# City not found. Skipping...
# Processing Record 33 of Set 1 | Walvis Bay
# Processing Record 34 of Set 1 | Jatiroto
# Processing Record 35 of Set 1 | Grindavik
# Processing Record 36 of Set 1 | Toora-Khem
# Processing Record 37 of Set 1 | Pevek
# Processing Record 38 of Set 1 | Kaitangata
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 39 of Set 1 | Hovd
# Processing Record 40 of Set 1 | Butaritari
# Processing Record 41 of Set 1 | Lebu
# Processing Record 42 of Set 1 | Punta Arenas
# City not found. Skipping...
# Processing Record 43 of Set 1 | Lazaro Cardenas
# Processing Record 44 of Set 1 | Cherskiy
# Processing Record 45 of Set 1 | Mastic Beach
# Processing Record 46 of Set 1 | Russell
# Processing Record 47 of Set 1 | Port Alfred
# City not found. Skipping...
# Processing Record 48 of Set 1 | Castro
# Processing Record 49 of Set 1 | Tuktoyaktuk
# Processing Record 50 of Set 1 | Ridgecrest
# Processing Record 1 of Set 2 | Calarasi
# Processing Record 2 of Set 2 | Atuona
# Processing Record 3 of Set 2 | Rikitea
# Processing Record 4 of Set 2 | Xuddur
# Processing Record 5 of Set 2 | Takoradi
# Processing Record 6 of Set 2 | Upernavik
# Processing Record 7 of Set 2 | Yashkul
# Processing Record 8 of Set 2 | Peniche
# Processing Record 9 of Set 2 | Zhireken
# Processing Record 10 of Set 2 | Nizwa
# City not found. Skipping...
# Processing Record 11 of Set 2 | Kodiak
# Processing Record 12 of Set 2 | Waipawa
# Processing Record 13 of Set 2 | Lasa
# Processing Record 14 of Set 2 | Port Macquarie
# Processing Record 15 of Set 2 | Thomasville
# Processing Record 16 of Set 2 | Ozernovskiy
# Processing Record 17 of Set 2 | Dingle
# Processing Record 18 of Set 2 | Alofi
# Processing Record 19 of Set 2 | Avarua
# Processing Record 20 of Set 2 | Fortuna
# Processing Record 21 of Set 2 | Shenjiamen
# City not found. Skipping...
# Processing Record 22 of Set 2 | Yellowknife
# Processing Record 23 of Set 2 | Comodoro Rivadavia
# Processing Record 24 of Set 2 | Hay River
# Processing Record 25 of Set 2 | Mar del Plata
# Processing Record 26 of Set 2 | Hinckley
# Processing Record 27 of Set 2 | Jamestown
# Processing Record 28 of Set 2 | Omboue
# Processing Record 29 of Set 2 | Tazovskiy
# Processing Record 30 of Set 2 | Adrar
# Processing Record 31 of Set 2 | Longyearbyen
# Processing Record 32 of Set 2 | Nikolskoye
# Processing Record 33 of Set 2 | Nemuro
# City not found. Skipping...
# Processing Record 34 of Set 2 | Egvekinot
# Processing Record 35 of Set 2 | Severo-Kurilsk
# Processing Record 36 of Set 2 | Qeshm
# Processing Record 37 of Set 2 | The Pas
# Processing Record 38 of Set 2 | Senneterre
# Processing Record 39 of Set 2 | Thompson
# Processing Record 40 of Set 2 | Georgetown
# Processing Record 41 of Set 2 | Mangan
# Processing Record 42 of Set 2 | Hobart
# Processing Record 43 of Set 2 | Taltal
# Processing Record 44 of Set 2 | Dikson
# Processing Record 45 of Set 2 | Gorontalo
# Processing Record 46 of Set 2 | Bathsheba
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 47 of Set 2 | Pitimbu
# Processing Record 48 of Set 2 | Saint-Louis
# Processing Record 49 of Set 2 | Hermanus
# Processing Record 50 of Set 2 | Amga
# Processing Record 1 of Set 3 | Paamiut
# Processing Record 2 of Set 3 | Khandyga
# Processing Record 3 of Set 3 | Tiznit
# Processing Record 4 of Set 3 | Chuy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of Set 3 | New Norfolk
# Processing Record 6 of Set 3 | Henties Bay
# Processing Record 7 of Set 3 | Portland
# Processing Record 8 of Set 3 | Mount Gambier
# Processing Record 9 of Set 3 | Humaita
# Processing Record 10 of Set 3 | Lac
# Processing Record 11 of Set 3 | Bachaquero
# Processing Record 12 of Set 3 | Ribeira Grande
# Processing Record 13 of Set 3 | Norman Wells
# Processing Record 14 of Set 3 | Te Anau
# Processing Record 15 of Set 3 | Haines Junction
# Processing Record 16 of Set 3 | Kahului
# Processing Record 17 of Set 3 | Barrow
# Processing Record 18 of Set 3 | Nola
# City not found. Skipping...
# Processing Record 19 of Set 3 | Mahebourg
# Processing Record 20 of Set 3 | Hithadhoo
# Processing Record 21 of Set 3 | San Patricio
# Processing Record 22 of Set 3 | Sironj
# Processing Record 23 of Set 3 | Durazno
# Processing Record 24 of Set 3 | Carnarvon
# Processing Record 25 of Set 3 | Gainesville
# Processing Record 26 of Set 3 | Lompoc
# Processing Record 27 of Set 3 | Tommot
# Processing Record 28 of Set 3 | Pudozh
# Processing Record 29 of Set 3 | Port Blair
# Processing Record 30 of Set 3 | Palana
# Processing Record 31 of Set 3 | Biryusinsk
# Processing Record 32 of Set 3 | Talnakh
# Processing Record 33 of Set 3 | Pisco
# Processing Record 34 of Set 3 | Khorixas
# Processing Record 35 of Set 3 | Arraial do Cabo
# Processing Record 36 of Set 3 | Sisophon
# Processing Record 37 of Set 3 | Bethel
# Processing Record 38 of Set 3 | Bognor Regis
# Processing Record 39 of Set 3 | Ulladulla
# Processing Record 40 of Set 3 | Saskylakh
# Processing Record 41 of Set 3 | Plouzane
# Processing Record 42 of Set 3 | Erenhot
# Processing Record 43 of Set 3 | Swadlincote
# Processing Record 44 of Set 3 | Batagay-Alyta
# Processing Record 45 of Set 3 | Shima
# Processing Record 46 of Set 3 | Pacific Grove
# Processing Record 47 of Set 3 | Wamba
# Processing Record 48 of Set 3 | Cabo San Lucas
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of Set 3 | San Luis
# City not found. Skipping...
# Processing Record 50 of Set 3 | Chipinge
# Processing Record 1 of Set 4 | Santa Rosa
# Processing Record 2 of Set 4 | Acapulco
# Processing Record 3 of Set 4 | Sao Joao do Piaui
# Processing Record 4 of Set 4 | Port Elizabeth
# Processing Record 5 of Set 4 | Katsuura
# Processing Record 6 of Set 4 | Lodja
# Processing Record 7 of Set 4 | Sao Gabriel da Cachoeira
# Processing Record 8 of Set 4 | Coquimbo
# Processing Record 9 of Set 4 | Pangoa
# Processing Record 10 of Set 4 | Oriximina
# Processing Record 11 of Set 4 | Caravelas
# Processing Record 12 of Set 4 | Parabel
# Processing Record 13 of Set 4 | Hasaki
# Processing Record 14 of Set 4 | Pyu
# Processing Record 15 of Set 4 | Tevriz
# Processing Record 16 of Set 4 | Geraldton
# Processing Record 17 of Set 4 | Fukuma
# Processing Record 18 of Set 4 | Esperance
# City not found. Skipping...
# Processing Record 19 of Set 4 | Baykit
# Processing Record 20 of Set 4 | Tortosa
# Processing Record 21 of Set 4 | Lagoa
# Processing Record 22 of Set 4 | Rio Gallegos
# Processing Record 23 of Set 4 | Kindu
# Processing Record 24 of Set 4 | Luanda
# Processing Record 25 of Set 4 | Rio Grande
# Processing Record 26 of Set 4 | Havoysund
# Processing Record 27 of Set 4 | Sinazongwe
# Processing Record 28 of Set 4 | Watertown
# Processing Record 29 of Set 4 | Surovikino
# Processing Record 30 of Set 4 | Dwarka
# Processing Record 31 of Set 4 | Mandiana
# Processing Record 32 of Set 4 | Komsomolskiy
# Processing Record 33 of Set 4 | Hilo
# Processing Record 34 of Set 4 | Payson
# Processing Record 35 of Set 4 | La Ronge
# Processing Record 36 of Set 4 | Fontenay-le-Comte
# Processing Record 37 of Set 4 | Kolobrzeg
# Processing Record 38 of Set 4 | Bluff
# Processing Record 39 of Set 4 | Cobija
# Processing Record 40 of Set 4 | Karratha
# Processing Record 41 of Set 4 | Northam
# Processing Record 42 of Set 4 | Ancud
# Processing Record 43 of Set 4 | Lorengau
# Processing Record 44 of Set 4 | Puerto Pailas
# Processing Record 45 of Set 4 | Fare
# Processing Record 46 of Set 4 | Los Llanos de Aridane
# Processing Record 47 of Set 4 | Tiksi
# Processing Record 48 of Set 4 | Tilichiki
# Processing Record 49 of Set 4 | Nanortalik
# City not found. Skipping...
# Processing Record 50 of Set 4 | Yantal
# Processing Record 1 of Set 5 | Pasighat
# Processing Record 2 of Set 5 | Puerto Penasco
# Processing Record 3 of Set 5 | Iqaluit
# Processing Record 4 of Set 5 | Cayenne
# City not found. Skipping...
# Processing Record 5 of Set 5 | Alice Springs
# Processing Record 6 of Set 5 | Hualmay
# Processing Record 7 of Set 5 | Mogadishu
# Processing Record 8 of Set 5 | Cuamba
# Processing Record 9 of Set 5 | Nyurba
# Processing Record 10 of Set 5 | Yucca Valley
# Processing Record 11 of Set 5 | Cidreira
# Processing Record 12 of Set 5 | Qaanaaq
# Processing Record 13 of Set 5 | Solnechnyy
# Processing Record 14 of Set 5 | Pangnirtung
# Processing Record 15 of Set 5 | Luba
# Processing Record 16 of Set 5 | Constitucion
# Processing Record 17 of Set 5 | Rocha
# Processing Record 18 of Set 5 | Joacaba
# Processing Record 19 of Set 5 | Puerto Ayora
# Processing Record 20 of Set 5 | Lavrentiya
# Processing Record 21 of Set 5 | Touros
# Processing Record 22 of Set 5 | Turukhansk
# Processing Record 23 of Set 5 | Luderitz
# Processing Record 24 of Set 5 | Hambantota
# Processing Record 25 of Set 5 | Yumen
# Processing Record 26 of Set 5 | Vila Velha
# Processing Record 27 of Set 5 | Maragogi
# Processing Record 28 of Set 5 | Shimoda
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 5 | Kavieng
# Processing Record 30 of Set 5 | Bintulu
# Processing Record 31 of Set 5 | Clyde River
# Processing Record 32 of Set 5 | Namibe
# Processing Record 33 of Set 5 | Denpasar
# Processing Record 34 of Set 5 | Airai
# Processing Record 35 of Set 5 | Chokurdakh
# Processing Record 36 of Set 5 | Archidona
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 37 of Set 5 | Takanabe
# Processing Record 38 of Set 5 | Capaci
# Processing Record 39 of Set 5 | Cap Malheureux
# Processing Record 40 of Set 5 | San Policarpo
# Processing Record 41 of Set 5 | Carballo
# Processing Record 42 of Set 5 | Port Hardy
# Processing Record 43 of Set 5 | Sri Aman
# Processing Record 44 of Set 5 | Petatlan
# City not found. Skipping...
# Processing Record 45 of Set 5 | Tongliao
# Processing Record 46 of Set 5 | Narsaq
# Processing Record 47 of Set 5 | Saint Anthony
# Processing Record 48 of Set 5 | Sistranda
# Processing Record 49 of Set 5 | Shiyan
# Processing Record 50 of Set 5 | Hamilton
# Processing Record 1 of Set 6 | Trelew
# Processing Record 2 of Set 6 | Palasbari
# Processing Record 3 of Set 6 | Necochea
# Processing Record 4 of Set 6 | Morgan City
# Processing Record 5 of Set 6 | Diffa
# Processing Record 6 of Set 6 | Winnemucca
# Processing Record 7 of Set 6 | Provideniya
# Processing Record 8 of Set 6 | Waingapu
# City not found. Skipping...
# Processing Record 9 of Set 6 | Goderich
# Processing Record 10 of Set 6 | Valparaiso
# Processing Record 11 of Set 6 | Victoria
# Processing Record 12 of Set 6 | Cam Ranh
# Processing Record 13 of Set 6 | Ha Giang
# Processing Record 14 of Set 6 | Khatanga
# Processing Record 15 of Set 6 | Ponta do Sol
# Processing Record 16 of Set 6 | Saint George
# Processing Record 17 of Set 6 | Huarmey
# Processing Record 18 of Set 6 | Daru
# Processing Record 19 of Set 6 | Zhanaozen
# Processing Record 20 of Set 6 | Kruisfontein
# Processing Record 21 of Set 6 | Bithur
# Processing Record 22 of Set 6 | Urusha
# Processing Record 23 of Set 6 | Panguna
# Processing Record 24 of Set 6 | Venado Tuerto
# Processing Record 25 of Set 6 | Port Arthur
# Processing Record 26 of Set 6 | Mashhad
# Processing Record 27 of Set 6 | The Valley
# Processing Record 28 of Set 6 | Preeceville
# Processing Record 29 of Set 6 | Cockburn Town
# Processing Record 30 of Set 6 | Port Keats
# Processing Record 31 of Set 6 | Krasnokamsk
# Processing Record 32 of Set 6 | Trincomalee
# Processing Record 33 of Set 6 | Mahina
# Processing Record 34 of Set 6 | Tual
# Processing Record 35 of Set 6 | Gander
# Processing Record 36 of Set 6 | Ust-Koksa
# Processing Record 37 of Set 6 | Beringovskiy
# Processing Record 38 of Set 6 | Harper
# Processing Record 39 of Set 6 | Saquarema
# Processing Record 40 of Set 6 | Aquiraz
# Processing Record 41 of Set 6 | Souillac
# Processing Record 42 of Set 6 | Rome
# Processing Record 43 of Set 6 | Sorland
# Processing Record 44 of Set 6 | Leningradskiy
# Processing Record 45 of Set 6 | Hirado
# Processing Record 46 of Set 6 | Kandrian
# Processing Record 47 of Set 6 | Marchena
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 48 of Set 6 | Kampot
# Processing Record 49 of Set 6 | Codrington
# Processing Record 50 of Set 6 | Quatre Cocos
# Processing Record 1 of Set 7 | Gigmoto
# Processing Record 2 of Set 7 | Sambava
# Processing Record 3 of Set 7 | Husavik
# Processing Record 4 of Set 7 | Atasu
# Processing Record 5 of Set 7 | Buala
# Processing Record 6 of Set 7 | Tarakan
# Processing Record 7 of Set 7 | Kulhudhuffushi
# Processing Record 8 of Set 7 | Oranjemund
# Processing Record 9 of Set 7 | Saldanha
# Processing Record 10 of Set 7 | Makakilo City
# City not found. Skipping...
# Processing Record 11 of Set 7 | Torbay
# Processing Record 12 of Set 7 | Tura
# Processing Record 13 of Set 7 | Atar
# Processing Record 14 of Set 7 | Port Hedland
# Processing Record 15 of Set 7 | Fort Nelson
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 7 | Jumla
# City not found. Skipping...
# Processing Record 17 of Set 7 | Saint-Pierre
# Processing Record 18 of Set 7 | Danilov
# Processing Record 19 of Set 7 | Khani
# Processing Record 20 of Set 7 | Chavakachcheri
# Processing Record 21 of Set 7 | Ust-Nera
# Processing Record 22 of Set 7 | Yulara
# Processing Record 23 of Set 7 | Mana
# City not found. Skipping...
# Processing Record 24 of Set 7 | San Cristobal
# Processing Record 25 of Set 7 | Xining
# Processing Record 26 of Set 7 | Lakatoro
# Processing Record 27 of Set 7 | Mukhen
# Processing Record 28 of Set 7 | Gambat
# Processing Record 29 of Set 7 | Saint-Francois
# Processing Record 30 of Set 7 | Santa Isabel
# Processing Record 31 of Set 7 | Faanui
# Processing Record 32 of Set 7 | Macheng
# Processing Record 33 of Set 7 | Usta Muhammad
# Processing Record 34 of Set 7 | Marinette
# Processing Record 35 of Set 7 | Ormara
# Processing Record 36 of Set 7 | Venice
# Processing Record 37 of Set 7 | Imbituba
# Processing Record 38 of Set 7 | Angoche
# Processing Record 39 of Set 7 | Pedernales
# Processing Record 40 of Set 7 | Coolum Beach
# City not found. Skipping...
# Processing Record 41 of Set 7 | Praia da Vitoria
# Processing Record 42 of Set 7 | Bodden Town
# Processing Record 43 of Set 7 | Batagay
# Processing Record 44 of Set 7 | Plettenberg Bay
# Processing Record 45 of Set 7 | North Bend
# Processing Record 46 of Set 7 | Copiapo
# Processing Record 47 of Set 7 | Bandarbeyla
# Processing Record 48 of Set 7 | Phan Thiet
# Processing Record 49 of Set 7 | Port Moresby
# Processing Record 50 of Set 7 | Kibala
# Processing Record 1 of Set 8 | Hwange
# Processing Record 2 of Set 8 | Asosa
# Processing Record 3 of Set 8 | Namatanai
# Processing Record 4 of Set 8 | Filadelfia
# Processing Record 5 of Set 8 | Itupiranga
# Processing Record 6 of Set 8 | Avera
# Processing Record 7 of Set 8 | Mukhtolovo
# Processing Record 8 of Set 8 | Volgodonsk
# Processing Record 9 of Set 8 | Pirogovo
# City not found. Skipping...
# Processing Record 10 of Set 8 | Uarini
# Processing Record 11 of Set 8 | Ushtobe
# Processing Record 12 of Set 8 | Vanimo
# Processing Record 13 of Set 8 | Sur
# Processing Record 14 of Set 8 | Ixtapa
# Processing Record 15 of Set 8 | Calabozo
# Processing Record 16 of Set 8 | Meulaboh
# Processing Record 17 of Set 8 | Muborak
# Processing Record 18 of Set 8 | Pershotravneve
# Processing Record 19 of Set 8 | Greencastle
# Processing Record 20 of Set 8 | Wilmington
# City not found. Skipping...
# Processing Record 21 of Set 8 | Oudtshoorn
# Processing Record 22 of Set 8 | Vaitape
# Processing Record 23 of Set 8 | Vardo
# Processing Record 24 of Set 8 | Steinbach
# Processing Record 25 of Set 8 | Hvide Sande
# Processing Record 26 of Set 8 | Chifeng
# Processing Record 27 of Set 8 | High Level
# Processing Record 28 of Set 8 | Thinadhoo
# Processing Record 29 of Set 8 | Miramar
# Processing Record 30 of Set 8 | Bambous Virieux
# City not found. Skipping...
# Processing Record 31 of Set 8 | Nileshwar
# Processing Record 32 of Set 8 | Camacupa
# Processing Record 33 of Set 8 | Qingdao
# Processing Record 34 of Set 8 | Baherden
# Processing Record 35 of Set 8 | Urazovka
# City not found. Skipping...
# Processing Record 36 of Set 8 | Cururupu
# City not found. Skipping...
# Processing Record 37 of Set 8 | Vetovo
# Processing Record 38 of Set 8 | Chimbote
# Processing Record 39 of Set 8 | Boli
# Processing Record 40 of Set 8 | Pinega
# Processing Record 41 of Set 8 | Ust-Barguzin
# Processing Record 42 of Set 8 | Dawei
# Processing Record 43 of Set 8 | Lardos
# Processing Record 44 of Set 8 | Gamba
# Processing Record 45 of Set 8 | San Andres
# Processing Record 46 of Set 8 | Madisonville
# Processing Record 47 of Set 8 | Nioki
# Processing Record 48 of Set 8 | Awbari
# Processing Record 49 of Set 8 | Kalabo
# Processing Record 50 of Set 8 | Escanaba
# Processing Record 1 of Set 9 | Igurusi
# Processing Record 2 of Set 9 | Brigantine
# Processing Record 3 of Set 9 | Anaco
# Processing Record 4 of Set 9 | Noumea
# Processing Record 5 of Set 9 | Kyshtovka
# Processing Record 6 of Set 9 | Novouzensk
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 9 | Kieta
# Processing Record 8 of Set 9 | Rossland
# Processing Record 9 of Set 9 | Guerrero Negro
# Processing Record 10 of Set 9 | Amahai
# Processing Record 11 of Set 9 | Byron Bay
# Processing Record 12 of Set 9 | Nanakuli
# Processing Record 13 of Set 9 | Berlevag
# Processing Record 14 of Set 9 | Tahe
# Processing Record 15 of Set 9 | Deputatskiy
# Processing Record 16 of Set 9 | Verkhneuralsk
# Processing Record 17 of Set 9 | Nome
# Processing Record 18 of Set 9 | Katherine
# Processing Record 19 of Set 9 | Nhulunbuy
# Processing Record 20 of Set 9 | Betsiamites
# Processing Record 21 of Set 9 | Qasigiannguit
# Processing Record 22 of Set 9 | Carmen
# Processing Record 23 of Set 9 | Polunochnoye
# Processing Record 24 of Set 9 | Pokhara
# Processing Record 25 of Set 9 | Khalkhal
# Processing Record 26 of Set 9 | Lomovka
# Processing Record 27 of Set 9 | Broken Hill
# Processing Record 28 of Set 9 | Morro Bay
# Processing Record 29 of Set 9 | Half Moon Bay
# Processing Record 30 of Set 9 | Aklavik
# Processing Record 31 of Set 9 | Kungurtug
# Processing Record 32 of Set 9 | Margate
# Processing Record 33 of Set 9 | Kamaishi
# Processing Record 34 of Set 9 | Santiago del Estero
# Processing Record 35 of Set 9 | Maple Creek
# Processing Record 36 of Set 9 | Maturin
# Processing Record 37 of Set 9 | Nivala
# Processing Record 38 of Set 9 | Semey
# Processing Record 39 of Set 9 | Mehamn
# City not found. Skipping...
# Processing Record 40 of Set 9 | Upata
# Processing Record 41 of Set 9 | Muisne
# Processing Record 42 of Set 9 | Fairbanks
# Processing Record 43 of Set 9 | Minot
# Processing Record 44 of Set 9 | Ambon
# City not found. Skipping...
# Processing Record 45 of Set 9 | Flin Flon
# Processing Record 46 of Set 9 | San Ramon
# Processing Record 47 of Set 9 | Vejprnice
# Processing Record 48 of Set 9 | Tambacounda
# Processing Record 49 of Set 9 | Barao de Melgaco
# Processing Record 50 of Set 9 | Ballina
# Processing Record 1 of Set 10 | Pangkalanbuun
# Processing Record 2 of Set 10 | Xichang
# Processing Record 3 of Set 10 | Port Hawkesbury
# City not found. Skipping...
# Processing Record 4 of Set 10 | Kilindoni
# Processing Record 5 of Set 10 | Leh
# Processing Record 6 of Set 10 | Mecca
# Processing Record 7 of Set 10 | Manokwari
# City not found. Skipping...
# Processing Record 8 of Set 10 | Vao
# Processing Record 9 of Set 10 | Dudinka
# Processing Record 10 of Set 10 | Kharan
# Processing Record 11 of Set 10 | San Pedro
# Processing Record 12 of Set 10 | Micheweni
# Processing Record 13 of Set 10 | Barra Patuca
# Processing Record 14 of Set 10 | Agadez
# Processing Record 15 of Set 10 | Raahe
# Processing Record 16 of Set 10 | Eyl
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 17 of Set 10 | Les Cayes
# Processing Record 18 of Set 10 | Hargeysa
# Processing Record 19 of Set 10 | Bonavista
# Processing Record 20 of Set 10 | Alyangula
# Processing Record 21 of Set 10 | Naze
# Processing Record 22 of Set 10 | Kasama
# Processing Record 23 of Set 10 | Hervey Bay
# Processing Record 24 of Set 10 | San Angelo
# Processing Record 25 of Set 10 | Opuwo
# Processing Record 26 of Set 10 | Mayo
# Processing Record 27 of Set 10 | Yajalon
# Processing Record 28 of Set 10 | Matara
# Processing Record 29 of Set 10 | Kupang
# Processing Record 30 of Set 10 | Bhuj
# Processing Record 31 of Set 10 | Dombarovskiy
# Processing Record 32 of Set 10 | Pindi Bhattian
# Processing Record 33 of Set 10 | Anito
# Processing Record 34 of Set 10 | Pondicherry
# Processing Record 35 of Set 10 | Coihaique
# Processing Record 36 of Set 10 | Petropavlovsk-Kamchatskiy
# Processing Record 37 of Set 10 | Santa Cruz
# Processing Record 38 of Set 10 | Bagdarin
# Processing Record 39 of Set 10 | Kubinka
# Processing Record 40 of Set 10 | Aksarka
# Processing Record 41 of Set 10 | Itaituba
# City not found. Skipping...
# Processing Record 42 of Set 10 | Pascagoula
# Processing Record 43 of Set 10 | Ardabil
# Processing Record 44 of Set 10 | Tlaltenango
# Processing Record 45 of Set 10 | Mezhova
# Processing Record 46 of Set 10 | Poretskoye
# Processing Record 47 of Set 10 | Brewster
# Processing Record 48 of Set 10 | North Platte
# City not found. Skipping...
# Processing Record 49 of Set 10 | Maningrida
# Processing Record 50 of Set 10 | Vigrestad
# Processing Record 1 of Set 11 | Madinat Sittah Uktubar
# Processing Record 2 of Set 11 | Severo-Yeniseyskiy
# Processing Record 3 of Set 11 | Maxixe
# Processing Record 4 of Set 11 | Suntar
# Processing Record 5 of Set 11 | Juba
# Processing Record 6 of Set 11 | Bekhtery
# Processing Record 7 of Set 11 | Tautira
# Processing Record 8 of Set 11 | Luis Correia
# Processing Record 9 of Set 11 | Padang
# Processing Record 10 of Set 11 | Gumdag
# Processing Record 11 of Set 11 | Kyabe
# Processing Record 12 of Set 11 | Karlskrona
# Processing Record 13 of Set 11 | Zihuatanejo
# Processing Record 14 of Set 11 | Camacha
# Processing Record 15 of Set 11 | Sola
# Processing Record 16 of Set 11 | Morros
# Processing Record 17 of Set 11 | Isiro
# Processing Record 18 of Set 11 | Vestmanna
# Processing Record 19 of Set 11 | Suluova
# Processing Record 20 of Set 11 | Banda Aceh
# Processing Record 21 of Set 11 | Barcelos
# Processing Record 22 of Set 11 | Gambela
# Processing Record 23 of Set 11 | Otavi
# Processing Record 24 of Set 11 | Urubicha
# Processing Record 25 of Set 11 | Santa Cruz Cabralia
# Processing Record 26 of Set 11 | Mae Sai
# Processing Record 27 of Set 11 | Visby
# Processing Record 28 of Set 11 | Umm Kaddadah
# Processing Record 29 of Set 11 | Dengzhou
# Processing Record 30 of Set 11 | Viedma
# Processing Record 31 of Set 11 | Whitianga
# City not found. Skipping...
# Processing Record 32 of Set 11 | Stuttgart
# Processing Record 33 of Set 11 | Saint-Joseph
# Processing Record 34 of Set 11 | Kargil
# Processing Record 35 of Set 11 | Baiyin
# Processing Record 36 of Set 11 | Roald
# Processing Record 37 of Set 11 | Kysyl-Syr
# Processing Record 38 of Set 11 | Bilma
# Processing Record 39 of Set 11 | Qinhuangdao
# Processing Record 40 of Set 11 | Penco
# Processing Record 41 of Set 11 | Beloha
# Processing Record 42 of Set 11 | Galway
# Processing Record 43 of Set 11 | Skjervoy
# Processing Record 44 of Set 11 | Sitka
# Processing Record 45 of Set 11 | Oistins
# Processing Record 46 of Set 11 | Bela
# City not found. Skipping...
# Processing Record 47 of Set 11 | Tavda
# Processing Record 48 of Set 11 | Mount Isa
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
#Covert Raw Data to DataFrame

weather_table = {
    "City":city_name,
    "Cloudiness":cloudiness,
    "Country":country,
    "Date":date,
    "Humidity":humidity,
    "Lat":lat,
    "Lng":lng,
    "Max Temp":max_temp,
    "Wind Speed":wind_speed
}

# %%
#converting to Data Frame
weather_df = pd.DataFrame(weather_table)
weather_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Port-Gentil          20      GA  1566663006        74  -0.72    8.78
# 1      Mataura          97      NZ  1566663008        84 -46.19  168.86
# 2      Ushuaia          40      AR  1566663009        65 -54.81  -68.31
# 3     Sobolevo           0      RU  1566663010        74  54.43   31.90
# 4        Vaini          97      IN  1566663011        89  15.34   74.49
#
#    Max Temp  Wind Speed
# 0     80.60       11.41
# 1     44.01        1.99
# 2     46.40        3.36
# 3     68.76        7.11
# 4     77.04        2.95

# %%
#perform count on data frame, to make sure all columns are filled
weather_df.count()
# Out:
# City          548
# Cloudiness    548
# Country       548
# Date          548
# Humidity      548
# Lat           548
# Lng           548
# Max Temp      548
# Wind Speed    548
# dtype: int64

# %%
#saving Data Frame to csv and export it to output file
weather_df.to_csv("output/weather_df.csv", index = False, header = True)

# %%
#Latitude vs. Temperature Plot
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], edgecolors="black",
           facecolors="royalblue")
plt.title("City Latitude vs. Max Temperature (08/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("figures/fig1.png")
plt.grid(True)
plt.show()

# %%
#Latitude vs. Humidity
plt.scatter(weather_df["Lat"], weather_df["Humidity"], edgecolors="black",
           facecolors="royalblue")
plt.title("City Latitude vs. Humidity (08/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("figures/fig2.png")
plt.grid(True)
plt.show()

# %%
#Latitude vs. Cloudiness
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], edgecolors="black",
           facecolors="royalblue")
plt.title("City Latitude vs. Cloudiness (08/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("figures/fig3.png")
plt.grid(True)
plt.show()

# %%
#Latitude vs. Wind Speed
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], edgecolors="black",
           facecolors="royalblue")
plt.title("City Latitude vs. Wind Speed (08/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("figures/fig4.png")
plt.grid(True)
plt.show()
