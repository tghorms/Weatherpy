# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
api_key = "39042e07c1158e77a43c5d806d2b6125"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={api_key}&units={units}&q="

# %%
city_name = []
country = []
date = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []

record = 0
set_starter = 1

print("Beginning Data Retrieval")

print("--------------------------------")

for city in cities:
   
    try:
        response = requests.get(f"{query_url}{city}").json()
        #city_name.append(response["name"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        
        if record > 49:
            record = 1
            set_starter += 1
            city_name.append(response["name"])
        else:
            record += 1
            city_name.append(response["name"])
            
        print(f"Processing Record {record} of Set {set_starter} | {city_record}")
        
        time.sleep(1.02)
              
    except :
              print("City not found. Skipping...")
              
    continue

print("-------------------------------")
print("Data Retrieval Complete")
print("-------------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of Set 1 | Rikitea
# Processing Record 2 of Set 1 | Albany
# Processing Record 3 of Set 1 | New Norfolk
# City not found. Skipping...
# Processing Record 4 of Set 1 | Te Anau
# Processing Record 5 of Set 1 | Dunedin
# Processing Record 6 of Set 1 | Mataura
# Processing Record 7 of Set 1 | Kupang
# Processing Record 8 of Set 1 | Hilo
# Processing Record 9 of Set 1 | Hermanus
# Processing Record 10 of Set 1 | East London
# City not found. Skipping...
# Processing Record 11 of Set 1 | Ushuaia
# City not found. Skipping...
# Processing Record 12 of Set 1 | Hithadhoo
# Processing Record 13 of Set 1 | Hobart
# City not found. Skipping...
# Processing Record 14 of Set 1 | Atuona
# City not found. Skipping...
# Processing Record 15 of Set 1 | Cavalcante
# Processing Record 16 of Set 1 | Beringovskiy
# Processing Record 17 of Set 1 | Jiayuguan
# City not found. Skipping...
# Processing Record 18 of Set 1 | Pevek
# Processing Record 19 of Set 1 | Coquimbo
# Processing Record 20 of Set 1 | Aksu
# Processing Record 21 of Set 1 | Severo-Kurilsk
# Processing Record 22 of Set 1 | Vaini
# Processing Record 23 of Set 1 | Corner Brook
# Processing Record 24 of Set 1 | Bredasdorp
# Processing Record 25 of Set 1 | Punta Arenas
# Processing Record 26 of Set 1 | Henderson
# Processing Record 27 of Set 1 | Dhidhdhoo
# City not found. Skipping...
# Processing Record 28 of Set 1 | Mahebourg
# Processing Record 29 of Set 1 | Victoria
# Processing Record 30 of Set 1 | Dikson
# Processing Record 31 of Set 1 | Apollonia
# Processing Record 32 of Set 1 | Jamestown
# City not found. Skipping...
# Processing Record 33 of Set 1 | Nadym
# Processing Record 34 of Set 1 | Faanui
# Processing Record 35 of Set 1 | Ribeira Grande
# Processing Record 36 of Set 1 | Barguzin
# Processing Record 37 of Set 1 | Kapaa
# Processing Record 38 of Set 1 | Kolosovka
# Processing Record 39 of Set 1 | Yamethin
# Processing Record 40 of Set 1 | Puerto Ayora
# Processing Record 41 of Set 1 | North Vernon
# Processing Record 42 of Set 1 | Naze
# Processing Record 43 of Set 1 | Lasa
# Processing Record 44 of Set 1 | Seoul
# Processing Record 45 of Set 1 | Pa Sang
# City not found. Skipping...
# Processing Record 46 of Set 1 | Fort Frances
# City not found. Skipping...
# Processing Record 47 of Set 1 | Ilulissat
# Processing Record 48 of Set 1 | Lagoa
# City not found. Skipping...
# Processing Record 49 of Set 1 | Dodge City
# Processing Record 50 of Set 1 | Yamada
# Processing Record 51 of Set 1 | Russell
# Processing Record 1 of Set 2 | Tuatapere
# Processing Record 2 of Set 2 | Eureka
# Processing Record 3 of Set 2 | Sechura
# City not found. Skipping...
# Processing Record 4 of Set 2 | Lavrentiya
# Processing Record 5 of Set 2 | Mmabatho
# Processing Record 6 of Set 2 | Brae
# Processing Record 7 of Set 2 | Busselton
# Processing Record 8 of Set 2 | Havre-Saint-Pierre
# Processing Record 9 of Set 2 | Vestmannaeyjar
# Processing Record 10 of Set 2 | Yellowknife
# Processing Record 11 of Set 2 | Kulhudhuffushi
# Processing Record 12 of Set 2 | Alakurtti
# Processing Record 13 of Set 2 | Qaanaaq
# Processing Record 14 of Set 2 | Bethel
# Processing Record 15 of Set 2 | Pervomayskoye
# Processing Record 16 of Set 2 | Umm Kaddadah
# City not found. Skipping...
# Processing Record 17 of Set 2 | Kruisfontein
# Processing Record 18 of Set 2 | Hasaki
# Processing Record 19 of Set 2 | Tateyama
# Processing Record 20 of Set 2 | Bambous Virieux
# Processing Record 21 of Set 2 | Cape Town
# Processing Record 22 of Set 2 | Gazojak
# Processing Record 23 of Set 2 | Hualmay
# Processing Record 24 of Set 2 | Castro
# Processing Record 25 of Set 2 | Balkhash
# Processing Record 26 of Set 2 | Avarua
# Processing Record 27 of Set 2 | Mazamari
# Processing Record 28 of Set 2 | Turukhansk
# Processing Record 29 of Set 2 | Darhan
# City not found. Skipping...
# Processing Record 30 of Set 2 | Thompson
# Processing Record 31 of Set 2 | Baruun-Urt
# Processing Record 32 of Set 2 | Carnarvon
# Processing Record 33 of Set 2 | Khatanga
# Processing Record 34 of Set 2 | Dingle
# Processing Record 35 of Set 2 | Chokurdakh
# Processing Record 36 of Set 2 | Sigli
# Processing Record 37 of Set 2 | Pacific Grove
# Processing Record 38 of Set 2 | Boyolangu
# Processing Record 39 of Set 2 | Port Lincoln
# Processing Record 40 of Set 2 | Wajir
# Processing Record 41 of Set 2 | Biak
# Processing Record 42 of Set 2 | Luangwa
# Processing Record 43 of Set 2 | Vila
# Processing Record 44 of Set 2 | Tuktoyaktuk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 2 | Bluff
# Processing Record 46 of Set 2 | Tasiilaq
# Processing Record 47 of Set 2 | Flin Flon
# Processing Record 48 of Set 2 | Kavieng
# Processing Record 49 of Set 2 | High Level
# Processing Record 50 of Set 2 | Nosy Varika
# City not found. Skipping...
# Processing Record 51 of Set 2 | Kaeo
# Processing Record 1 of Set 3 | Kaitangata
# Processing Record 2 of Set 3 | Pangody
# City not found. Skipping...
# Processing Record 3 of Set 3 | Ponta do Sol
# City not found. Skipping...
# Processing Record 4 of Set 3 | Ancud
# Processing Record 5 of Set 3 | Longyearbyen
# Processing Record 6 of Set 3 | Ladario
# Processing Record 7 of Set 3 | Marsa Matruh
# City not found. Skipping...
# Processing Record 8 of Set 3 | Tungor
# Processing Record 9 of Set 3 | Voskresenskoye
# Processing Record 10 of Set 3 | Malatya
# Processing Record 11 of Set 3 | Terrace
# Processing Record 12 of Set 3 | Pirovskoye
# Processing Record 13 of Set 3 | Loandjili
# Processing Record 14 of Set 3 | Grand Gaube
# Processing Record 15 of Set 3 | Hofn
# Processing Record 16 of Set 3 | Hamilton
# Processing Record 17 of Set 3 | Port Alfred
# Processing Record 18 of Set 3 | Mar del Plata
# Processing Record 19 of Set 3 | Ljungby
# Processing Record 20 of Set 3 | Evensk
# Processing Record 21 of Set 3 | Beidao
# Processing Record 22 of Set 3 | Alice Springs
# Processing Record 23 of Set 3 | Torbay
# City not found. Skipping...
# Processing Record 24 of Set 3 | Barrow
# Processing Record 25 of Set 3 | Saint-Philippe
# Processing Record 26 of Set 3 | Laurel
# Processing Record 27 of Set 3 | Poya
# Processing Record 28 of Set 3 | Requena
# Processing Record 29 of Set 3 | Port Blair
# City not found. Skipping...
# Processing Record 30 of Set 3 | Show Low
# Processing Record 31 of Set 3 | Praia da Vitoria
# Processing Record 32 of Set 3 | Butaritari
# Processing Record 33 of Set 3 | Jijiang
# Processing Record 34 of Set 3 | Falun
# Processing Record 35 of Set 3 | Thai Binh
# Processing Record 36 of Set 3 | Flinders
# Processing Record 37 of Set 3 | Kholodnyy
# Processing Record 38 of Set 3 | Tiksi
# Processing Record 39 of Set 3 | Yumen
# Processing Record 40 of Set 3 | Inongo
# Processing Record 41 of Set 3 | Mayor Pablo Lagerenza
# Processing Record 42 of Set 3 | Ahipara
# Processing Record 43 of Set 3 | Qasigiannguit
# Processing Record 44 of Set 3 | Constitucion
# Processing Record 45 of Set 3 | Leningradskiy
# City not found. Skipping...
# Processing Record 46 of Set 3 | Lao Cai
# Processing Record 47 of Set 3 | Adrar
# Processing Record 48 of Set 3 | Sabak
# Processing Record 49 of Set 3 | Lebu
# Processing Record 50 of Set 3 | Esperance
# Processing Record 51 of Set 3 | Miandrivazo
# Processing Record 1 of Set 4 | Lobito
# Processing Record 2 of Set 4 | Nhulunbuy
# Processing Record 3 of Set 4 | Alofi
# Processing Record 4 of Set 4 | Mnogovershinnyy
# City not found. Skipping...
# Processing Record 5 of Set 4 | Nandu
# Processing Record 6 of Set 4 | Sorland
# Processing Record 7 of Set 4 | Touros
# Processing Record 8 of Set 4 | Vila Franca do Campo
# Processing Record 9 of Set 4 | Port Hedland
# Processing Record 10 of Set 4 | Port Elizabeth
# Processing Record 11 of Set 4 | Kavaratti
# Processing Record 12 of Set 4 | Sharan
# Processing Record 13 of Set 4 | La Presa
# Processing Record 14 of Set 4 | Isilkul
# Processing Record 15 of Set 4 | Sao Filipe
# Processing Record 16 of Set 4 | Dubai
# Processing Record 17 of Set 4 | Chabahar
# Processing Record 18 of Set 4 | Damavand
# Processing Record 19 of Set 4 | Fort Nelson
# Processing Record 20 of Set 4 | Saldanha
# Processing Record 21 of Set 4 | Barranca
# Processing Record 22 of Set 4 | Yulara
# Processing Record 23 of Set 4 | Mecca
# Processing Record 24 of Set 4 | Trelew
# City not found. Skipping...
# Processing Record 25 of Set 4 | Hobyo
# Processing Record 26 of Set 4 | Mareeba
# Processing Record 27 of Set 4 | Bonthe
# Processing Record 28 of Set 4 | Haines Junction
# Processing Record 29 of Set 4 | Kununurra
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 30 of Set 4 | Kodiak
# Processing Record 31 of Set 4 | Cabo San Lucas
# Processing Record 32 of Set 4 | Sistranda
# Processing Record 33 of Set 4 | Podlesnoye
# Processing Record 34 of Set 4 | Upernavik
# Processing Record 35 of Set 4 | Ialibu
# Processing Record 36 of Set 4 | Dunmore East
# Processing Record 37 of Set 4 | Ixtapa
# Processing Record 38 of Set 4 | Morant Bay
# City not found. Skipping...
# Processing Record 39 of Set 4 | San Vicente
# Processing Record 40 of Set 4 | Chuy
# Processing Record 41 of Set 4 | Quang Ngai
# Processing Record 42 of Set 4 | Jinka
# Processing Record 43 of Set 4 | Varhaug
# Processing Record 44 of Set 4 | Cherskiy
# Processing Record 45 of Set 4 | Kurchum
# Processing Record 46 of Set 4 | Mahanoro
# Processing Record 47 of Set 4 | Klaksvik
# Processing Record 48 of Set 4 | Harnosand
# Processing Record 49 of Set 4 | Komsomolskiy
# Processing Record 50 of Set 4 | Zhangye
# City not found. Skipping...
# Processing Record 51 of Set 4 | Pisco
# Processing Record 1 of Set 5 | Norman Wells
# Processing Record 2 of Set 5 | Ostrovnoy
# Processing Record 3 of Set 5 | Saint-Joseph
# Processing Record 4 of Set 5 | Leh
# Processing Record 5 of Set 5 | Piacabucu
# Processing Record 6 of Set 5 | Ballina
# Processing Record 7 of Set 5 | Milkovo
# Processing Record 8 of Set 5 | Turbat
# Processing Record 9 of Set 5 | Vostok
# Processing Record 10 of Set 5 | Merauke
# Processing Record 11 of Set 5 | Georgetown
# Processing Record 12 of Set 5 | Barroso
# Processing Record 13 of Set 5 | Svetlogorsk
# Processing Record 14 of Set 5 | Barsovo
# Processing Record 15 of Set 5 | Luderitz
# Processing Record 16 of Set 5 | Sitka
# Processing Record 17 of Set 5 | La Ronge
# Processing Record 18 of Set 5 | Northam
# Processing Record 19 of Set 5 | Arraial do Cabo
# Processing Record 20 of Set 5 | Petropavlovsk-Kamchatskiy
# Processing Record 21 of Set 5 | Goderich
# Processing Record 22 of Set 5 | Ostersund
# Processing Record 23 of Set 5 | Viedma
# Processing Record 24 of Set 5 | Port Hardy
# Processing Record 25 of Set 5 | Kutum
# Processing Record 26 of Set 5 | Okhotsk
# Processing Record 27 of Set 5 | Bambanglipuro
# Processing Record 28 of Set 5 | Road Town
# Processing Record 29 of Set 5 | Kingsville
# Processing Record 30 of Set 5 | Penzance
# Processing Record 31 of Set 5 | Laguna
# Processing Record 32 of Set 5 | Ginir
# Processing Record 33 of Set 5 | Margate
# Processing Record 34 of Set 5 | Gamba
# Processing Record 35 of Set 5 | Chunhuhub
# Processing Record 36 of Set 5 | Cidreira
# Processing Record 37 of Set 5 | Bom Jesus
# Processing Record 38 of Set 5 | Walker
# Processing Record 39 of Set 5 | Miramar
# City not found. Skipping...
# Processing Record 40 of Set 5 | Murwillumbah
# Processing Record 41 of Set 5 | Cockburn Town
# Processing Record 42 of Set 5 | Shache
# Processing Record 43 of Set 5 | Obo
# City not found. Skipping...
# Processing Record 44 of Set 5 | Puerto Quijarro
# Processing Record 45 of Set 5 | Mana
# Processing Record 46 of Set 5 | Saint George
# Processing Record 47 of Set 5 | Kirakira
# Processing Record 48 of Set 5 | Diapaga
# Processing Record 49 of Set 5 | Vila Velha
# Processing Record 50 of Set 5 | Alcudia
# Processing Record 51 of Set 5 | Szczecinek
# Processing Record 1 of Set 6 | Puerto Colombia
# Processing Record 2 of Set 6 | Airai
# City not found. Skipping...
# Processing Record 3 of Set 6 | Rio Grande
# City not found. Skipping...
# Processing Record 4 of Set 6 | Port Macquarie
# City not found. Skipping...
# Processing Record 5 of Set 6 | Zaysan
# Processing Record 6 of Set 6 | Bilibino
# City not found. Skipping...
# Processing Record 7 of Set 6 | Ilebo
# Processing Record 8 of Set 6 | Nantucket
# Processing Record 9 of Set 6 | Hyeres
# Processing Record 10 of Set 6 | Bathsheba
# Processing Record 11 of Set 6 | Luau
# Processing Record 12 of Set 6 | Rexburg
# City not found. Skipping...
# Processing Record 13 of Set 6 | Katsuura
# Processing Record 14 of Set 6 | Clyde River
# City not found. Skipping...
# Processing Record 15 of Set 6 | Berlevag
# City not found. Skipping...
# Processing Record 16 of Set 6 | Todos Santos
# Processing Record 17 of Set 6 | Sibolga
# Processing Record 18 of Set 6 | Juru
# Processing Record 19 of Set 6 | Yar-Sale
# Processing Record 20 of Set 6 | Paamiut
# Processing Record 21 of Set 6 | Chimbote
# Processing Record 22 of Set 6 | Arman
# Processing Record 23 of Set 6 | Mount Isa
# Processing Record 24 of Set 6 | Synya
# Processing Record 25 of Set 6 | Kudahuvadhoo
# Processing Record 26 of Set 6 | Butembo
# Processing Record 27 of Set 6 | Sinnamary
# Processing Record 28 of Set 6 | Alamosa
# Processing Record 29 of Set 6 | Camopi
# Processing Record 30 of Set 6 | Riyadh
# City not found. Skipping...
# Processing Record 31 of Set 6 | Anadyr
# Processing Record 32 of Set 6 | Ordu
# Processing Record 33 of Set 6 | Santa Cruz de la Palma
# Processing Record 34 of Set 6 | Los Llanos de Aridane
# Processing Record 35 of Set 6 | Korem
# Processing Record 36 of Set 6 | Salinopolis
# Processing Record 37 of Set 6 | Muroto
# Processing Record 38 of Set 6 | Nemuro
# City not found. Skipping...
# Processing Record 39 of Set 6 | Catalina
# Processing Record 40 of Set 6 | Mpulungu
# Processing Record 41 of Set 6 | Zalari
# Processing Record 42 of Set 6 | Stephenville Crossing
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 6 | Guerrero Negro

# %%
#Covert Raw Data to DataFrame

weather_table = {
    "City":city_name,
    "Cloudiness":cloudiness,
    "Country":country,
    "Date":date,
    "Humidity":humidity,
    "Lat":lat,
    "Lng":lng,
    "Max Temp":max_temp,
    "Wind Speed":wind_speed
}

# %%
weather_df = pd.DataFrame(weather_table)
weather_df.head()

# %%
weather_df.count()

# %%
weather_df.to_csv("output/weather_df.csv", index = False, header = True)

# %%
#Latitude vs. Temperature Plot
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], edgecolors="black",
           facecolors="royalblue")
plt.title("City Latitude vs. Max Temperature (08/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("figures/fig1.png")
plt.grid(True)
plt.show()

# %%
#Latitude vs. Humidity
plt.scatter(weather_df["Lat"], weather_df["Humidity"], edgecolors="black",
           facecolors="royalblue")
plt.title("City Latitude vs. Humidity (08/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("figures/fig2.png")
plt.grid(True)
plt.show()

# %%
#Latitude vs. Cloudiness
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], edgecolors="black",
           facecolors="royalblue")
plt.title("City Latitude vs. Cloudiness (08/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("figures/fig3.png")
plt.grid(True)
plt.show()

# %%
#Latitude vs. Wind Speed
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], edgecolors="black",
           facecolors="royalblue")
plt.title("City Latitude vs. Wind Speed (08/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("figures/fig4.png")
plt.grid(True)
plt.show()
